# %% [markdown]
# # Aula 1
#
# ## Fazendo as primeiras Visualizações

# %% [markdown]
# ### Importando as Bibliotecas

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import datetime

# %% [markdown]
# ### Importando os dados

# %%
df = pd.read_csv('monitoramento_tempo.csv')

# %%
df.head()
# Out:
#    temperatura  pressão  humidade  direção do vento  velocidade do vento  \
# 0   282.080000   1024.0      81.0               0.0                  0.0
# 1   282.080000   1024.0      81.0               0.0                  0.0
# 2   282.083252   1024.0      80.0               4.0                  0.0
# 3   282.091866   1024.0      80.0              18.0                  0.0
# 4   282.100481   1024.0      80.0              31.0                  0.0
#
#   dia_da_semana                 data
# 0       Domingo  2012-10-01 12:00:00
# 1       Domingo  2012-10-01 13:00:00
# 2       Domingo  2012-10-01 14:00:00
# 3       Domingo  2012-10-01 15:00:00
# 4       Domingo  2012-10-01 16:00:00

# %% [markdown]
# ### Fazendo verificação dos dados recebidos
#
# Podemos fazer a transformação de Object (String) para um Datetime, facilitando trabalhos futuros

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45253 entries, 0 to 45252
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   temperatura          45253 non-null  float64
#  1   pressão              45253 non-null  float64
#  2   humidade             45253 non-null  float64
#  3   direção do vento     45253 non-null  float64
#  4   velocidade do vento  45253 non-null  float64
#  5   dia_da_semana        45253 non-null  object
#  6   data                 45253 non-null  object
# dtypes: float64(5), object(2)
# memory usage: 2.4+ MB

# %%
df['data']=pd.to_datetime(df['data'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45253 entries, 0 to 45252
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   temperatura          45253 non-null  float64
#  1   pressão              45253 non-null  float64
#  2   humidade             45253 non-null  float64
#  3   direção do vento     45253 non-null  float64
#  4   velocidade do vento  45253 non-null  float64
#  5   dia_da_semana        45253 non-null  object
#  6   data                 45253 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), float64(5), object(1)
# memory usage: 2.4+ MB

# %%
plt.figure(figsize =(15,8))
plt.plot(df['data'],df['temperatura'])

# %%
plt.figure(figsize =(15,8))
plt.title("Temperatura X Tempo", )
plt.plot(df['data'],df['temperatura'])

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])
eixo.set_title("Temperatura no momento",fontsize=25)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data',fontsize=20) 
eixo.legend(['temperatura'], loc = 'lower left', fontsize = 18)
eixo.plot(df['data'], df['temperatura'], color = '#FF3323')

# %% [markdown]
# # Aula 2
#
# ### Customizando nossas visualizações

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])
eixo.set_title("Temperatura no momento",fontsize=25)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data',fontsize=20) 
eixo.legend(['temperatura'], loc = 'lower left', fontsize = 18)
eixo.plot(df['data'], df['temperatura'], color = '#FF3323')

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])
eixo.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1))
eixo.set_title("Temperatura no momento",fontsize=25)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data',fontsize=20) 
eixo.legend(['temperatura'], loc = 'lower left', fontsize = 18)
eixo.plot(df['data'], df['temperatura'], color = '#FF3323', lw = 0.5)

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])
eixo.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,2))
eixo.set_title("Temperatura no momento",fontsize=25)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data',fontsize=20) 
eixo.grid(True)
eixo.plot(df['data'], df['temperatura'], color = '#FF3323', lw = 0.5)
eixo.legend(['temperatura'], loc = 'lower right', fontsize = 15)

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])
eixo2 = fig.add_axes([0.7,0.65,0.3,0.3])

eixo.plot(df['data'], df['temperatura'], color = 'r')
eixo.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1))
eixo.set_title('Temperatura registrada', fontsize = 25, pad=10)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data',fontsize=20) 
eixo.grid(True)
eixo.legend(['Temperatura'], loc='lower right', fontsize=15)

eixo2.plot(df['data'], df['temperatura'], color = 'b')
eixo2.set_title('Temperatura registrada', fontsize = 13)
eixo2.set_ylabel('Temperatura', fontsize=8)
eixo2.set_xlabel('Data',fontsize=8) 
eixo2.grid(True)

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])
eixo2 = fig.add_axes([0.7,0.65,0.3,0.3])

eixo.plot(df['data'], df['temperatura'], color = 'r')
eixo.set_xlim(datetime.datetime(2014,5,1),datetime.datetime(2014,6,1))
eixo.set_ylim(270,320)
eixo.set_title('Temperatura em Maio/2014', fontsize = 25, pad=10)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data',fontsize=20) 
eixo.grid(True)
eixo.legend(['Temperatura'], loc='lower right', fontsize=15)

eixo2.plot(df['data'], df['temperatura'], color = 'b')
eixo2.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1))
eixo2.set_title('Temperatura 2014', fontsize = 13)
eixo2.set_ylabel('Temperatura', fontsize=8)
eixo2.set_xlabel('Data',fontsize=8) 
eixo2.grid(True)

# %%
fig = plt.figure(figsize=(15,8))
eixo = fig.add_axes([0,0,1,1])
eixo2 = fig.add_axes([0.7,0.65,0.3,0.3])

eixo.plot(df['data'], df['temperatura'], color = 'r')
eixo.set_xlim(datetime.datetime(2014,5,1),datetime.datetime(2014,6,1))
eixo.set_ylim(270,320)
eixo.set_title('Temperatura em Maio/2014', fontsize = 25, pad=10)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.set_xlabel('Data',fontsize=20) 
eixo.grid(True)
eixo.legend(['Temperatura'], loc='lower right', fontsize=15)

azul_esquerda = df['data'] < datetime.datetime(2014,5,1)
azul_direita = df['data'] > datetime.datetime(2014,6,1)

eixo2.plot(df['data'], df['temperatura'], color = 'r')
eixo2.plot(df[azul_esquerda]['data'],df[azul_esquerda]['temperatura'], color = 'b')
eixo2.plot(df[azul_direita]['data'],df[azul_direita]['temperatura'], color = 'b')
eixo2.set_xlim(datetime.datetime(2014,1,1),datetime.datetime(2015,1,1))
eixo2.set_title('Temperatura 2014', fontsize = 13)
eixo2.set_ylabel('Temperatura', fontsize=8)
eixo2.set_xlabel('Data',fontsize=8) 
eixo2.grid(True)

# %% [markdown]
# # Aula 3
#
# ### Marcando anotações e limitantes

# %%
fig = plt.figure(figsize = (15,8))

eixo = fig.add_axes([0,0,1,1])

eixo.plot(df['data'], df['temperatura'], color = 'g')
eixo.set_title('Temperatura', fontsize=25, pad=20)
eixo.set_xlabel('Data', fontsize=20)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.legend(['Temperatura'], loc='lower right', fontsize=15)
eixo.grid(True)

x1 = df['data'][df['temperatura'].idxmax()]
y1 = max(df['temperatura'])

eixo.annotate("Máximo", xy=(x1,y1), fontsize = 20)

eixo.axhline(max(df['temperatura']),color = 'k',linestyle='dashed')
eixo.axhline(min(df['temperatura']),color = 'k',linestyle='dashed')

# %%
fig = plt.figure(figsize = (15,8))

eixo = fig.add_axes([0,0,1,1])

eixo.plot(df['data'], df['temperatura'], color = 'g')
eixo.set_title('Temperatura', fontsize=25, pad=20)
eixo.set_xlabel('Data', fontsize=20)
eixo.set_ylabel('Temperatura', fontsize=20)
eixo.legend(['Temperatura'], loc='lower right', fontsize=15)
eixo.grid(True)

x1 = df['data'][df['temperatura'].idxmax()]
y1 = max(df['temperatura'])

x2 = df['data'][df['temperatura'].idxmax() - 7000]
y2 =max(df['temperatura']) - 5

eixo.annotate("Máximo", xy=(x1,y1), fontsize = 20, xytext = (x2,y2), arrowprops = dict(facecolor='k'))

x1 = df['data'][df['temperatura'].idxmin()]
y1 = min(df['temperatura'])

x2 = df['data'][df['temperatura'].idxmin() - 7000]
y2 = min(df['temperatura']) + 5
eixo.annotate("Mínimo", xy=(x1,y1), fontsize = 20, xytext = (x2,y2), arrowprops = dict(facecolor='k'))

eixo.axhline(max(df['temperatura']),color = 'k',linestyle='dashed')
eixo.axhline(min(df['temperatura']),color = 'k',linestyle='dashed')

# %%
temperatura_por_dia_da_semana = df.groupby('dia_da_semana')['temperatura'].mean()
nome_dias = ['Domingo', 'Segunda', 'Terça', 'Quarta', 'Quinta', 'Sexta','Sábado']
temperatura_por_dia_da_semana = temperatura_por_dia_da_semana[nome_dias]
temperatura_por_dia_da_semana
# Out:
# dia_da_semana
# Domingo    285.009095
# Segunda    284.985382
# Terça      284.892811
# Quarta     284.998290
# Quinta     285.000643
# Sexta      285.060886
# Sábado     285.003316
# Name: temperatura, dtype: float64

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

indice = range(len(temperatura_por_dia_da_semana))

eixo.bar(indice, temperatura_por_dia_da_semana, edgecolor='k')
eixo.set_title('Temperatura por dia da semana', fontsize=15,pad=10)
eixo.set_xlabel('Dia da Semana', fontsize = 10)
eixo.set_ylabel('Temperatura Média',fontsize=10)
eixo.set_xticks(indice)
eixo.set_xticklabels(nome_dias)
# Out:
# [Text(0, 0, 'Domingo'),
#  Text(1, 0, 'Segunda'),
#  Text(2, 0, 'Terça'),
#  Text(3, 0, 'Quarta'),
#  Text(4, 0, 'Quinta'),
#  Text(5, 0, 'Sexta'),
#  Text(6, 0, 'Sábado')]

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

eixo.pie(temperatura_por_dia_da_semana, labels = temperatura_por_dia_da_semana.index,
        autopct='%.1f%%')
# Out:
# ([<matplotlib.patches.Wedge at 0x1fc0b54f460>,
#   <matplotlib.patches.Wedge at 0x1fc0b54f370>,
#   <matplotlib.patches.Wedge at 0x1fc0b57c130>,
#   <matplotlib.patches.Wedge at 0x1fc0b57c7c0>,
#   <matplotlib.patches.Wedge at 0x1fc0b57ce50>,
#   <matplotlib.patches.Wedge at 0x1fc0b57d4e0>,
#   <matplotlib.patches.Wedge at 0x1fc0b57db70>],
#  [Text(0.9910535903556007, 0.47729737171209474, 'Domingo'),
#   Text(0.24473109278458755, 1.0724302738287752, 'Segunda'),
#   Text(-0.6857266170733417, 0.8601040673297335, 'Terça'),
#   Text(-1.099999956998096, 0.00030757793699097235, 'Quarta'),
#   Text(-0.6860615244195212, -0.8598369523992109, 'Quinta'),
#   Text(0.24462305235332962, -1.0724549231820144, 'Sexta'),
#   Text(0.9910579250318222, -0.47728837114643735, 'Sábado')],
#  [Text(0.5405746856485094, 0.2603440209338698, '14.3%'),
#   Text(0.13348968697341138, 0.5849619675429683, '14.3%'),
#   Text(-0.3740327002218227, 0.4691476730889455, '14.3%'),
#   Text(-0.599999976544416, 0.0001677697838132576, '14.3%'),
#   Text(-0.37421537695610246, -0.46900197403593313, '14.3%'),
#   Text(0.13343075582908887, -0.5849754126447351, '14.3%'),
#   Text(0.5405770500173575, -0.26033911153442035, '14.3%')])

# %%
fig = plt.figure(figsize=(5,4))
eixo = fig.add_axes([0,0,1,1])

explodir = [0.1,0,0,0,0,0,0.1]

eixo.pie(temperatura_por_dia_da_semana, labels = temperatura_por_dia_da_semana.index,
        autopct='%.1f%%', explode=explodir, shadow=True)
# Out:
# ([<matplotlib.patches.Wedge at 0x1fc0cc09000>,
#   <matplotlib.patches.Wedge at 0x1fc0cc08f10>,
#   <matplotlib.patches.Wedge at 0x1fc0cc0a170>,
#   <matplotlib.patches.Wedge at 0x1fc0cc0aa40>,
#   <matplotlib.patches.Wedge at 0x1fc0cc0b310>,
#   <matplotlib.patches.Wedge at 0x1fc0cc0bbe0>,
#   <matplotlib.patches.Wedge at 0x1fc0cc4c4f0>],
#  [Text(1.0811493712970188, 0.5206880418677398, 'Domingo'),
#   Text(0.24473109278458755, 1.0724302738287752, 'Segunda'),
#   Text(-0.6857266170733417, 0.8601040673297335, 'Terça'),
#   Text(-1.099999956998096, 0.00030757793699097235, 'Quarta'),
#   Text(-0.6860615244195212, -0.8598369523992109, 'Quinta'),
#   Text(0.24462305235332962, -1.0724549231820144, 'Sexta'),
#   Text(1.0811541000347151, -0.5206782230688407, 'Sábado')],
#  [Text(0.6306704665899276, 0.3037346910895148, '14.3%'),
#   Text(0.13348968697341138, 0.5849619675429683, '14.3%'),
#   Text(-0.3740327002218227, 0.4691476730889455, '14.3%'),
#   Text(-0.599999976544416, 0.0001677697838132576, '14.3%'),
#   Text(-0.37421537695610246, -0.46900197403593313, '14.3%'),
#   Text(0.13343075582908887, -0.5849754126447351, '14.3%'),
#   Text(0.6306732250202504, -0.30372896345682376, '14.3%')])
